# %%
file = open("report.txt", "r")

# %%
file = open("C:/Users/Administrator/Desktop/report2.txt", "r")

# %%
file = open("report.txt", "r")
print(file.read())
# Out:
# 'Smit CDE Batch 05'

# %%
file = open("report-3.txt", "w")
# always close your file 
file.close()

# %%
with open("report.txt", "r") as file:
    content = file.read()

# File is closed here automatically, even if an error occurred
print(content)
# Out:
# Smit batch 05
# Server restarted at 02:14
# Backup completed successfully
# 3 failed login attempts flagged

# %%
content = file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 content = file.read()
#
# ValueError: I/O operation on closed file.

# %%
with open("report.txt", "r") as file:
    content = file.readline() # returns first line 

# File is closed here automatically, even if an error occurred
print(content)
# Out:
# Smit batch 05

# %%
with open("report.txt", "r") as file:
    content = file.readlines()

# File is closed here automatically, even if an error occurred
print(content)
for line in content[:2]:
    print(line.strip())
# Out:
# ['Smit batch 05\n', 'Server restarted at 02:14\n', 'Backup completed successfully\n', '3 failed login attempts flagged']
# Smit batch 05
# Server restarted at 02:14

# %%
with open("summary.txt", "w") as f:
    f.write("Pipeline run: complete\n")
    f.write("Records processed: 9500\n")
    f.write("Errors: 0\n")

# %%
with open("summary.txt", "w") as f:
    f.write("Pipeline run: Fail\n")

# %%
lines = [
    "Region: Asia Pacific\n",
    "Status: Active\n",
    "Clients: 14\n"
]

with open("region.txt", "w") as f:
    f.writelines(lines)

# %%
with open("region.txt", "a") as f:
    f.write("Pipeline run: Success\n")

# %%
with open("region.txt", "r") as f:
    print(f.read())
# Out:
# Region: Asia Pacific
# Status: Active
# Clients: 14
# Pipeline run: Fail
# Pipeline run: Success

# %%
# openpyxl, pandas

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.6-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 3.4 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.8 MB 7.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 12.4 MB/s eta 0:00:00
# Downloading numpy-2.4.6-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----------------- ---------------------- 5.2/12.3 MB 53.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 30.9 MB/s eta 0:00:00
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.4.6 pandas-3.0.3 tzdata-2026.2
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import csv

with open("employees.csv", "r") as f:
    reader = csv.DictReader(f)
    # print(reader)
    for row in reader:
        print(row["id"], "—", row["status"])
# Out:
# 1 — active
# 2 — active
# 3 — inactive

# %%
import csv

records = [
    {"id": 1, "name": "Alice", "department": "Engineering", "status": "active"},
    {"id": 2, "name": "Bob",   "department": "Finance",     "status": "active"},
]

with open("output.csv", "w", newline="") as f:
    fieldnames = ["id", "name", "department", "status"]
    writer = csv.DictWriter(f, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(records)

# %%
import json


response = '{"status": "ok", "records": 4200, "errors": null}'
data = json.loads(response)

print(data)
# Out:
# {'status': 'ok', 'records': 4200, 'errors': None}

# %%
print(type(data))
print(data["status"])
print(data["records"])
print(data["errors"])
# Out:
# <class 'dict'>
# ok
# 4200
# None

# %%
result = {
    "pipeline": "daily_load",
    "rows_loaded": 9500,
    "success": True
}

json_string = json.dumps(result,indent=1)
print(json_string,)
print(type(json_string))
# Out:
# {
#  "pipeline": "daily_load",
#  "rows_loaded": 9500,
#  "success": true
# }
# <class 'str'>

# %%
import json
data = {"host": "localhost", "port": 5432}
with open("config.json", "w") as f:
    json.dump(data, f, indent=4)

# %%
# dump vs dumps
